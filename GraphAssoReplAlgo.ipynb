# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AssoReplAlgo.csv')
df
# Out:
#    Replacement Algo.  Cache Size  Hit Ratio
# 0             Random           4       44.2
# 1             Random           8       48.9
# 2             Random          16       70.0
# 3             Random          32       84.0
# 4             Random          64       90.8
# 5               FIFO           4       42.0
# 6               FIFO           8       46.1
# 7               FIFO          16       61.1
# 8               FIFO          32       86.2
# 9               FIFO          64       88.5
# 10               LRU           4       42.1
# 11               LRU           8       46.1
# 12               LRU          16       69.8
# 13               LRU          32       86.2
# 14               LRU          64       89.0

# %%
random = df.iloc[0:5,]
fifo = df.iloc[5:10,]
lru = df.iloc[10:15,]
# random.info()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(random['Cache Size'], random['Hit Ratio'], color='tab:blue',label="Random")
ax.plot(fifo['Cache Size'], fifo['Hit Ratio'], color='tab:orange',label="FIFO")
ax.plot(lru['Cache Size'], lru['Hit Ratio'], color='tab:green',label="LRU")
ax.set_xlabel('Cache Size')
ax.set_ylabel('Hit Ratio')
ax.legend()
plt.show()
